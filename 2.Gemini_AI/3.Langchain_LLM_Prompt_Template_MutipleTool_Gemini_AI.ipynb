# %%
from IPython.display import display, HTML

innerHtml = """
<div style="
    max-width:1000px;
    margin:20px auto;
    padding:30px;
    font-family:'Segoe UI', Arial, sans-serif;
    background:linear-gradient(135deg,#0F172A,#7C3AED);
    border-radius:20px;
    color:white;
    box-shadow:0 10px 30px rgba(0,0,0,0.3);
">

    <h1 style="text-align:center;">
        🛠️ LangChain Multiple Tools Workflow
    </h1>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:20px;
    ">
        <h2 style="color:#7C3AED;">🔑 Step 1: Load API Key</h2>
        <p>
            Reads the OpenAI API key from the <b>.env</b> file to securely connect to GPT-4.1-mini.
        </p>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#7C3AED;">🤖 Step 2: Initialize the LLM</h2>
        <p>
            Creates a GPT model which will be shared across multiple tools.
        </p>

        <div style="
            background:#F3F4F6;
            padding:12px;
            border-radius:5px;
            font-family:monospace;
        ">
            ChatOpenAI → GPT-4.1-mini
        </div>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#7C3AED;">❓ Step 3: Create Simple QA Tool</h2>

        <p>
            This tool is designed to answer user questions clearly.
        </p>

        <div style="
            background:#EEF2FF;
            padding:12px;
            border-radius:8px;
        ">
            User Question → Prompt → GPT Model → Answer
        </div>

        <p style="margin-top:10px;">
            Example:
        </p>

        <div style="
            background:#DBEAFE;
            padding:10px;
            border-radius:5px;
        ">
            "What is LangGraph in LangChain?"
        </div>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#7C3AED;">📝 Step 4: Create Summarizer Tool</h2>

        <p>
            This tool is designed to shorten long text into a concise summary.
        </p>

        <div style="
            background:#EEF2FF;
            padding:12px;
            border-radius:8px;
        ">
            Long Text → Prompt → GPT Model → Summary
        </div>

        <p style="margin-top:10px;">
            Example:
        </p>

        <div style="
            background:#DBEAFE;
            padding:10px;
            border-radius:5px;
        ">
            Input: Long paragraph about LangGraph
            <br><br>
            Output: Short summary
        </div>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#7C3AED;">🔍 Why Create Two Different Tools?</h2>

        <table style="width:100%;border-collapse:collapse;">
            <tr style="background:#E5E7EB;">
                <th style="padding:10px;">Tool</th>
                <th style="padding:10px;">Purpose</th>
            </tr>
            <tr>
                <td style="padding:10px;"><b>Simple QA</b></td>
                <td style="padding:10px;">Answers factual questions.</td>
            </tr>
            <tr>
                <td style="padding:10px;"><b>Summarizer</b></td>
                <td style="padding:10px;">Summarizes large blocks of text.</td>
            </tr>
        </table>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#7C3AED;">🚀 Step 5: Invoke the Tools</h2>

        <p>
            The code executes each tool independently.
        </p>

        <div style="
            background:#EEF2FF;
            padding:15px;
            border-radius:10px;
        ">
            qa_tool.invoke(question)
            <br><br>
            summary_tool.invoke(text)
        </div>

        <p style="margin-top:10px;">
            Each tool processes different types of input and returns the appropriate output.
        </p>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#7C3AED;">📺 Step 6: Display Results</h2>

        <p>
            The outputs from both tools are displayed on the screen.
        </p>

        <ul>
            <li>✅ QA Tool returns an answer.</li>
            <li>✅ Summarizer Tool returns a summary.</li>
        </ul>
    </div>

    <div style="
        margin-top:25px;
        background:#22C55E;
        color:white;
        padding:20px;
        border-radius:15px;
        text-align:center;
        font-size:18px;
    ">
        <b>
        🔄 Overall Architecture
        <br><br>

        Shared GPT Model
        <br>
        ⬇️
        <br><br>

        ┌───────────────┐ &nbsp;&nbsp;&nbsp;&nbsp; ┌────────────────┐
        <br>
        │ Simple QA Tool │ &nbsp;&nbsp;&nbsp;&nbsp; │ Summarizer Tool │
        <br>
        └───────────────┘ &nbsp;&nbsp;&nbsp;&nbsp; └────────────────┘

        <br><br>
        ⬇️
        <br><br>

        Answers Questions & Summarizes Text
        </b>
    </div>

    <div style="
        margin-top:20px;
        background:#FEF3C7;
        color:#92400E;
        padding:20px;
        border-radius:15px;
    ">
        <b>💡 Layman Explanation</b>
        <br><br>

        Think of GPT as an employee.
        <br><br>

        The <b>Simple QA Tool</b> gives that employee the job of answering questions.
        <br><br>

        The <b>Summarizer Tool</b> gives the same employee the job of creating summaries.
        <br><br>

        Both tools use the same AI model, but each tool has a different responsibility and purpose.
    </div>

</div>
"""

display(HTML(innerHtml))
# Out:
# <div style="
#     max-width:1000px;
#     margin:20px auto;
#     padding:30px;
#     font-family:'Segoe UI', Arial, sans-serif;
#     background:linear-gradient(135deg,#0F172A,#7C3AED);
#     border-radius:20px;
#     color:white;
#     box-shadow:0 10px 30px rgba(0,0,0,0.3);
# ">
#
#     <h1 style="text-align:center;">
#         🛠️ LangChain Multiple Tools Workflow
#     </h1>
#
#     <div style="
#         background:white;
#         color:#333;
#         padding:20px;
#         border-radius:15px;
#         margin-top:20px;
#     ">
#         <h2 style="color:#7C3AED;">🔑 Step 1: Load API Key</h2>
#         <p>
#             Reads the OpenAI API key from the <b>.env</b> file to securely connect to GPT-4.1-mini.
#         </p>
#     </div>
#
#     <div style="
#         background:white;
#         color:#333;
#         padding:20px;
#         border-radius:15px;
#         margin-top:15px;
#     ">
#         <h2 style="color:#7C3AED;">🤖 Step 2: Initialize the LLM</h2>
# ...

# %%
import os
from dotenv import load_dotenv
#from langchain.chat_models import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI
#from langchain.prompts import PromptTemplate
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.tools import Tool

# 🔐 Load API keys
load_dotenv(dotenv_path=".env")

# 🔸 Initialize the LLM
llm = ChatGoogleGenerativeAI(
    model="models/gemini-3.5-flash",
    temperature=0,
    api_key=os.getenv("GOOGLE_API_KEY")
)

# ==========================================================
# ✅ Tool 1: Simple QA Tool
# ==========================================================

qa_prompt = ChatPromptTemplate.from_template(
    "Answer clearly: {question}"
)

qa_chain = qa_prompt | llm

qa_tool = Tool(
    name="Simple QA",
    func=lambda question: qa_chain.invoke(
        {"question": question}
    ).content[0]["text"],
    description="Answer factual questions clearly"
)

# ==========================================================
# ✅ Tool 2: Summarizer Tool
# ==========================================================

summary_prompt = ChatPromptTemplate.from_template(
    "Summarize the following text:\n\n{text}"
)

summary_chain = summary_prompt | llm

summary_tool = Tool(
    name="Summarizer",
    func=lambda text: summary_chain.invoke(
        {"text": text}
    ).content[0]["text"],
    description="Summarizes input text"
)

# ==========================================================
# 🔧 Tool Usage Examples
# ==========================================================

qa_query = "What is LangGraph in LangChain?"

summary_text = """
LangGraph is a library built on top of LangChain that helps developers create
stateful, multi-step agents as graphs. Each node represents a step like calling
an LLM or a tool. It's ideal for advanced AI workflows.
"""

# ==========================================================
# 🚀 Run Tools
# ==========================================================

print("\n" + "=" * 60)
print("🧠 SIMPLE QA TOOL OUTPUT")
print("=" * 60)
print(qa_tool.invoke(qa_query))

print("\n" + "=" * 60)
print("📝 SUMMARIZER TOOL OUTPUT")
print("=" * 60)
print(summary_tool.invoke(summary_text))
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# ...
# 🧠 SIMPLE QA TOOL OUTPUT
# ...
# **LangGraph** is an extension of LangChain designed for building **stateful, multi-actor applications with LLMs (Large Language Models)**.
#
# In simple terms, it is a framework that allows you to build complex AI agents that can loop, make decisions, remember past steps, and work together.
#
# Here is a clear breakdown of what LangGraph is, why it is used, and how it works:
#
# ---
#
# ### 1. Why do we need LangGraph? (The Problem it Solves)
# Standard LangChain is great for linear workflows (Chain of Thought: Step A $\rightarrow$ Step B $\rightarrow$ Step C). This is called a **DAG** (Directed Acyclic Graph), meaning the data only flows in one direction.
#
# ...
