# %%
from IPython.display import display, HTML

innerHtml = """
<div style="
    max-width:1000px;
    margin:20px auto;
    padding:30px;
    font-family:'Segoe UI', Arial, sans-serif;
    background:linear-gradient(135deg,#1E293B,#7C3AED);
    border-radius:20px;
    color:white;
    box-shadow:0 10px 30px rgba(0,0,0,0.3);
">

    <h1 style="text-align:center;">
        🛠️ LangChain Multi-Tool Workflow
    </h1>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:20px;
    ">
        <h2 style="color:#7C3AED;">🔑 Step 1: Load API Keys</h2>
        <p>
            The application loads OpenAI and Tavily API keys from the
            <b>.env</b> file so it can securely access AI services and web search.
        </p>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#7C3AED;">🤖 Step 2: Initialize GPT Model</h2>
        <p>
            A GPT-4.1-mini model is created and acts as the central AI brain
            for multiple tools.
        </p>

        <div style="
            background:#EEF2FF;
            padding:12px;
            border-radius:8px;
            text-align:center;
            font-weight:bold;
        ">
            GPT-4.1-mini 🧠
        </div>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#7C3AED;">❓ Tool 1: Simple QA Tool</h2>

        <p>
            This tool answers user questions using GPT.
        </p>

        <div style="
            background:#DBEAFE;
            padding:12px;
            border-radius:8px;
        ">
            User Question → Prompt Template → GPT → Answer
        </div>

        <p style="margin-top:10px;">
            Example:
            <br>
            <b>"What is LangGraph in LangChain?"</b>
        </p>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#7C3AED;">📝 Tool 2: Summarizer Tool</h2>

        <p>
            This tool converts long text into a short summary.
        </p>

        <div style="
            background:#DBEAFE;
            padding:12px;
            border-radius:8px;
        ">
            Long Text → GPT → Summary
        </div>

        <p style="margin-top:10px;">
            Ideal for articles, reports, emails, or documentation.
        </p>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#7C3AED;">🌐 Tool 3: Tavily Search Tool</h2>

        <p>
            This tool searches the internet for current information.
        </p>

        <div style="
            background:#DBEAFE;
            padding:12px;
            border-radius:8px;
        ">
            Search Query → Tavily Search → Internet Results
        </div>

        <p style="margin-top:10px;">
            Example:
            <br>
            <b>"Latest updates on GPT-4o"</b>
        </p>

        <p>
            Unlike the first two tools, Tavily retrieves real-time web data instead
            of generating answers from the LLM.
        </p>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#7C3AED;">🚀 Step 3: Execute the Tools</h2>

        <p>
            Each tool is tested with sample input using:
        </p>

        <div style="
            background:#EEF2FF;
            padding:15px;
            border-radius:8px;
            font-family:monospace;
        ">
            tool.invoke(...)
        </div>

        <p>
            The invoke() method runs the selected tool and returns the result.
        </p>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#7C3AED;">📺 Expected Outputs</h2>

        <ul style="line-height:2;">
            <li>✅ Simple QA Tool returns an answer.</li>
            <li>✅ Summarizer Tool returns a concise summary.</li>
            <li>✅ Tavily Search returns current web search results.</li>
        </ul>
    </div>

    <div style="
        margin-top:25px;
        background:#22C55E;
        color:white;
        padding:20px;
        border-radius:15px;
        text-align:center;
        font-size:18px;
    ">
        <b>
        🔄 Overall Workflow
        <br><br>

        User Input
        <br>⬇️<br>

        Choose Tool
        <br>⬇️<br>

        ┌────────────┐
        <br>
        │ QA Tool    │
        <br>
        │ Summary Tool│
        <br>
        │ Search Tool│
        <br>
        └────────────┘

        <br>⬇️<br>

        GPT or Tavily Processes Request

        <br>⬇️<br>

        Final Result Displayed
        </b>
    </div>

    <div style="
        margin-top:20px;
        background:#FEF3C7;
        color:#92400E;
        padding:20px;
        border-radius:15px;
    ">
        <b>💡 Layman Explanation</b>
        <br><br>

        Imagine you have three assistants:
        <br><br>

        🧠 Assistant 1 answers questions.
        <br>
        📝 Assistant 2 creates summaries.
        <br>
        🌐 Assistant 3 searches the internet.
        <br><br>

        All assistants have a specific responsibility and can be used independently.
        This is exactly how LangChain Tools work.
    </div>

</div>
"""

display(HTML(innerHtml))
# Out:
# <div style="
#     max-width:1000px;
#     margin:20px auto;
#     padding:30px;
#     font-family:'Segoe UI', Arial, sans-serif;
#     background:linear-gradient(135deg,#1E293B,#7C3AED);
#     border-radius:20px;
#     color:white;
#     box-shadow:0 10px 30px rgba(0,0,0,0.3);
# ">
#
#     <h1 style="text-align:center;">
#         🛠️ LangChain Multi-Tool Workflow
#     </h1>
#
#     <div style="
#         background:white;
#         color:#333;
#         padding:20px;
#         border-radius:15px;
#         margin-top:20px;
#     ">
#         <h2 style="color:#7C3AED;">🔑 Step 1: Load API Keys</h2>
#         <p>
#             The application loads OpenAI and Tavily API keys from the
#             <b>.env</b> file so it can securely access AI services and web search.
#         </p>
#     </div>
#
#     <div style="
#         background:white;
#         color:#333;
#         padding:20px;
#         border-radius:15px;
#         margin-top:15px;
#     ">
# ...

# %%
import os
from dotenv import load_dotenv
#from langchain.chat_models import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI
#from langchain.prompts import PromptTemplate
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.tools import Tool
from langchain_tavily import TavilySearch

# 🔐 Load API Keys
load_dotenv(dotenv_path=".env")

# 🔸 Initialize LLM
llm = ChatGoogleGenerativeAI(
    model="models/gemini-3.5-flash",
    temperature=0,
    api_key=os.getenv("GOOGLE_API_KEY")
)
# ✅ Tool 1: Simple QA

qa_prompt = ChatPromptTemplate.from_template(
    "Answer clearly: {question}"
)

qa_chain = qa_prompt | llm

qa_tool = Tool(
    name="Simple QA",
    func=lambda question: qa_chain.invoke(
        {"question": question}
    ).content[0]["text"],
    description="Answer factual questions clearly"
)

# ✅ Tool 2: Summarizer

summary_prompt = ChatPromptTemplate.from_template(
    "Summarize the following text:\n\n{text}"
)

summary_chain = summary_prompt | llm

summary_tool = Tool(
    name="Summarizer",
    func=lambda text: summary_chain.invoke(
        {"text": text}
    ).content[0]["text"],
    description="Summarizes input text"
)

# ✅ Tool 3: Web Search (Tavily)

search_tool = TavilySearch(
    max_results=3,
    tavily_api_key=os.getenv("TAVILY_API_KEY")
)

# 🧪 Test Inputs

qa_query = "What is LangGraph in LangChain?"

summary_text = """
LangGraph is a framework for building stateful multi-step agents using LangChain.
It uses graph-based design to model agent workflows and memory.
"""

search_query = "Latest updates on GPT-4o by OpenAI"

# 🚀 Run Tools
print("\n" + "=" * 60)
print("\n🧠 Simple QA Tool Output:\n")
print("\n" + "=" * 60)
print(qa_tool.invoke(qa_query))

print("\n" + "=" * 60)
print("\n📝 Summarizer Tool Output:\n")
print("\n" + "=" * 60)
print(summary_tool.invoke(summary_text))

print("\n" + "=" * 60)
print("\n🌐 Web Search Tool Output:\n")
print("\n" + "=" * 60)
print(search_tool.invoke(search_query))
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# ...
#
# 🧠 Simple QA Tool Output:
#
#
# ...
# **LangGraph** is an extension of LangChain designed for building **stateful, multi-agent applications with LLMs**.
#
# While standard LangChain is great for creating linear chains of actions (Step A $\rightarrow$ Step B $\rightarrow$ Step C), LangGraph is built to handle **loops (cycles)** and **complex decision-making**.
#
# Here is a clear breakdown of what it is, why it matters, and how it works.
#
# ---
#
# ### 1. Why do we need LangGraph?
# In traditional LangChain, workflows are **DAGs** (Directed Acyclic Graphs), meaning they only move forward.
#
# However, real-world AI agents often need to loop. For example:
# 1. **Ask LLM** to write code.
# ...
