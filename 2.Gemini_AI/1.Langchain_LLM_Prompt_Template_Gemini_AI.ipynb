# %%
from IPython.display import display, HTML

innerHtml = """
<div style="
    max-width:900px;
    margin:20px auto;
    padding:30px;
    font-family:'Segoe UI',Arial,sans-serif;
    background:linear-gradient(135deg,#10B981,#2563EB);
    border-radius:20px;
    color:white;
    box-shadow:0 10px 30px rgba(0,0,0,0.25);
">

    <h1 style="text-align:center;">
        🤖 LangChain + OpenAI Workflow
    </h1>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:20px;
    ">
        <h2 style="color:#2563EB;">🔑 Step 1: Load OpenAI API Key</h2>
        <p>
            Reads the OpenAI API key from the <b>.env</b> file to securely connect to OpenAI services.
        </p>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#2563EB;">🚀 Step 2: Connect to OpenAI</h2>
        <p>
            Initializes an OpenAI model such as <b>GPT-4o</b> or <b>GPT-4o-mini</b> using the API key.
        </p>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#2563EB;">📝 Step 3: Create Prompt Template</h2>
        <p>
            Creates a reusable prompt template.
        </p>
        <div style="
            background:#f4f4f4;
            padding:10px;
            border-left:5px solid #2563EB;
            border-radius:5px;
        ">
            Answer clearly: {question}
        </div>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#2563EB;">🔗 Step 4: Create the Chain</h2>
        <p>
            LangChain combines the Prompt Template and the OpenAI model into a single workflow (Chain).
        </p>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#2563EB;">❓ Step 5: Ask a Question</h2>
        <p>
            The user sends a question such as:
            <br>
            <b>What is LangGraph in LangChain?</b>
        </p>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#2563EB;">🧠 Step 6: OpenAI Processes the Request</h2>
        <p>
            The prompt and question are sent to the OpenAI model which understands the request and generates a response.
        </p>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#2563EB;">📺 Step 7: Display the Response</h2>
        <p>
            LangChain receives the answer from OpenAI and displays it back to the user.
        </p>
    </div>

    <div style="
        background:#ffffff20;
        margin-top:25px;
        padding:20px;
        border-radius:15px;
        text-align:center;
        font-size:18px;
    ">
        <b>
        🔄 Flow:
        Load API Key → Connect OpenAI → Create Prompt →
        Create Chain → Ask Question →
        OpenAI Generates Answer → Display Response
        </b>
    </div>

</div>
"""

display(HTML(innerHtml))
# Out:
# <div style="
#     max-width:900px;
#     margin:20px auto;
#     padding:30px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     background:linear-gradient(135deg,#10B981,#2563EB);
#     border-radius:20px;
#     color:white;
#     box-shadow:0 10px 30px rgba(0,0,0,0.25);
# ">
#
#     <h1 style="text-align:center;">
#         🤖 LangChain + OpenAI Workflow
#     </h1>
#
#     <div style="
#         background:white;
#         color:#333;
#         padding:20px;
#         border-radius:15px;
#         margin-top:20px;
#     ">
#         <h2 style="color:#2563EB;">🔑 Step 1: Load OpenAI API Key</h2>
#         <p>
#             Reads the OpenAI API key from the <b>.env</b> file to securely connect to OpenAI services.
#         </p>
#     </div>
#
#     <div style="
#         background:white;
#         color:#333;
#         padding:20px;
#         border-radius:15px;
#         margin-top:15px;
#     ">
#         <h2 style="color:#2563EB;">🚀 Step 2: Connect to OpenAI</h2>
# ...

# %%
import os
from dotenv import load_dotenv
#from langchain.chat_models import ChatOpenAI
from langchain_openai import ChatOpenAI
#from langchain.prompts import PromptTemplate
from langchain_core.prompts import ChatPromptTemplate    #change 
#from langchain.chains import LLMChain
from langchain_core.prompts import ChatPromptTemplate

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

# 🔐 Load API key
load_dotenv(dotenv_path=".env")

# 🔸 Initialize LLM
llm = ChatOpenAI(
    model="gpt-3.5-turbo",
    temperature=0,
    api_key=os.getenv("OPENAI_API_KEY")   # Optional if already in environment
)

# 🔸 Create Prompt Template
prompt = ChatPromptTemplate.from_template(
    "Answer clearly: {question}"
)

# 🔸 Create Chain (LCEL)
qa_chain = prompt | llm

# 🚀 Run a query
query = "What is LangGraph in LangChain?"

response = qa_chain.invoke(
    {"question": query}
)

# 🖨️ Output
print("\nUser Question:", query)
print("\nLLM Answer:", response.content)
# Out:
# User Question: What is LangGraph in LangChain?
#
# LLM Answer: LangGraph in LangChain is a graph database that stores and manages language data, including words, phrases, and their relationships. It is a key component of the LangChain platform, allowing for efficient storage and retrieval of language information for various applications.
