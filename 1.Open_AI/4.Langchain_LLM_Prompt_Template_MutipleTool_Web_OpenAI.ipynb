# %%
from IPython.display import display, HTML

innerHtml = """
<div style="
    max-width:1000px;
    margin:20px auto;
    padding:30px;
    font-family:'Segoe UI', Arial, sans-serif;
    background:linear-gradient(135deg,#1E293B,#7C3AED);
    border-radius:20px;
    color:white;
    box-shadow:0 10px 30px rgba(0,0,0,0.3);
">

    <h1 style="text-align:center;">
        🛠️ LangChain Multi-Tool Workflow
    </h1>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:20px;
    ">
        <h2 style="color:#7C3AED;">🔑 Step 1: Load API Keys</h2>
        <p>
            The application loads OpenAI and Tavily API keys from the
            <b>.env</b> file so it can securely access AI services and web search.
        </p>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#7C3AED;">🤖 Step 2: Initialize GPT Model</h2>
        <p>
            A GPT-4.1-mini model is created and acts as the central AI brain
            for multiple tools.
        </p>

        <div style="
            background:#EEF2FF;
            padding:12px;
            border-radius:8px;
            text-align:center;
            font-weight:bold;
        ">
            GPT-4.1-mini 🧠
        </div>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#7C3AED;">❓ Tool 1: Simple QA Tool</h2>

        <p>
            This tool answers user questions using GPT.
        </p>

        <div style="
            background:#DBEAFE;
            padding:12px;
            border-radius:8px;
        ">
            User Question → Prompt Template → GPT → Answer
        </div>

        <p style="margin-top:10px;">
            Example:
            <br>
            <b>"What is LangGraph in LangChain?"</b>
        </p>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#7C3AED;">📝 Tool 2: Summarizer Tool</h2>

        <p>
            This tool converts long text into a short summary.
        </p>

        <div style="
            background:#DBEAFE;
            padding:12px;
            border-radius:8px;
        ">
            Long Text → GPT → Summary
        </div>

        <p style="margin-top:10px;">
            Ideal for articles, reports, emails, or documentation.
        </p>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#7C3AED;">🌐 Tool 3: Tavily Search Tool</h2>

        <p>
            This tool searches the internet for current information.
        </p>

        <div style="
            background:#DBEAFE;
            padding:12px;
            border-radius:8px;
        ">
            Search Query → Tavily Search → Internet Results
        </div>

        <p style="margin-top:10px;">
            Example:
            <br>
            <b>"Latest updates on GPT-4o"</b>
        </p>

        <p>
            Unlike the first two tools, Tavily retrieves real-time web data instead
            of generating answers from the LLM.
        </p>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#7C3AED;">🚀 Step 3: Execute the Tools</h2>

        <p>
            Each tool is tested with sample input using:
        </p>

        <div style="
            background:#EEF2FF;
            padding:15px;
            border-radius:8px;
            font-family:monospace;
        ">
            tool.invoke(...)
        </div>

        <p>
            The invoke() method runs the selected tool and returns the result.
        </p>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#7C3AED;">📺 Expected Outputs</h2>

        <ul style="line-height:2;">
            <li>✅ Simple QA Tool returns an answer.</li>
            <li>✅ Summarizer Tool returns a concise summary.</li>
            <li>✅ Tavily Search returns current web search results.</li>
        </ul>
    </div>

    <div style="
        margin-top:25px;
        background:#22C55E;
        color:white;
        padding:20px;
        border-radius:15px;
        text-align:center;
        font-size:18px;
    ">
        <b>
        🔄 Overall Workflow
        <br><br>

        User Input
        <br>⬇️<br>

        Choose Tool
        <br>⬇️<br>

        ┌────────────┐
        <br>
        │ QA Tool    │
        <br>
        │ Summary Tool│
        <br>
        │ Search Tool│
        <br>
        └────────────┘

        <br>⬇️<br>

        GPT or Tavily Processes Request

        <br>⬇️<br>

        Final Result Displayed
        </b>
    </div>

    <div style="
        margin-top:20px;
        background:#FEF3C7;
        color:#92400E;
        padding:20px;
        border-radius:15px;
    ">
        <b>💡 Layman Explanation</b>
        <br><br>

        Imagine you have three assistants:
        <br><br>

        🧠 Assistant 1 answers questions.
        <br>
        📝 Assistant 2 creates summaries.
        <br>
        🌐 Assistant 3 searches the internet.
        <br><br>

        All assistants have a specific responsibility and can be used independently.
        This is exactly how LangChain Tools work.
    </div>

</div>
"""

display(HTML(innerHtml))
# Out:
# <div style="
#     max-width:1000px;
#     margin:20px auto;
#     padding:30px;
#     font-family:'Segoe UI', Arial, sans-serif;
#     background:linear-gradient(135deg,#1E293B,#7C3AED);
#     border-radius:20px;
#     color:white;
#     box-shadow:0 10px 30px rgba(0,0,0,0.3);
# ">
#
#     <h1 style="text-align:center;">
#         🛠️ LangChain Multi-Tool Workflow
#     </h1>
#
#     <div style="
#         background:white;
#         color:#333;
#         padding:20px;
#         border-radius:15px;
#         margin-top:20px;
#     ">
#         <h2 style="color:#7C3AED;">🔑 Step 1: Load API Keys</h2>
#         <p>
#             The application loads OpenAI and Tavily API keys from the
#             <b>.env</b> file so it can securely access AI services and web search.
#         </p>
#     </div>
#
#     <div style="
#         background:white;
#         color:#333;
#         padding:20px;
#         border-radius:15px;
#         margin-top:15px;
#     ">
#         <h2 style="color:#7C3AED;">🤖 Step 2: Initialize GPT Model</h2>
#         <p>
#             A GPT-4.1-mini model is created and acts as the central AI brain
#             for multiple tools.
#         </p>
#
#         <div style="
#             background:#EEF2FF;
#             padding:12px;
#             border-radius:8px;
#             text-align:center;
#             font-weight:bold;
#         ">
#             GPT-4.1-mini 🧠
#         </div>
#     </div>
#
#     <div style="
#         background:white;
#         color:#333;
#         padding:20px;
#         border-radius:15px;
#         margin-top:15px;
#     ">
#         <h2 style="color:#7C3AED;">❓ Tool 1: Simple QA Tool</h2>
#
#         <p>
#             This tool answers user questions using GPT.
#         </p>
#
#         <div style="
#             background:#DBEAFE;
#             padding:12px;
#             border-radius:8px;
#         ">
#             User Question → Prompt Template → GPT → Answer
#         </div>
#
#         <p style="margin-top:10px;">
#             Example:
#             <br>
#             <b>"What is LangGraph in LangChain?"</b>
#         </p>
#     </div>
#
#     <div style="
#         background:white;
#         color:#333;
#         padding:20px;
#         border-radius:15px;
#         margin-top:15px;
#     ">
#         <h2 style="color:#7C3AED;">📝 Tool 2: Summarizer Tool</h2>
#
#         <p>
#             This tool converts long text into a short summary.
#         </p>
#
#         <div style="
#             background:#DBEAFE;
#             padding:12px;
#             border-radius:8px;
#         ">
#             Long Text → GPT → Summary
#         </div>
#
#         <p style="margin-top:10px;">
#             Ideal for articles, reports, emails, or documentation.
#         </p>
#     </div>
#
#     <div style="
#         background:white;
#         color:#333;
#         padding:20px;
#         border-radius:15px;
#         margin-top:15px;
#     ">
#         <h2 style="color:#7C3AED;">🌐 Tool 3: Tavily Search Tool</h2>
#
#         <p>
#             This tool searches the internet for current information.
#         </p>
#
#         <div style="
#             background:#DBEAFE;
#             padding:12px;
#             border-radius:8px;
#         ">
#             Search Query → Tavily Search → Internet Results
#         </div>
#
#         <p style="margin-top:10px;">
#             Example:
#             <br>
#             <b>"Latest updates on GPT-4o"</b>
#         </p>
#
#         <p>
#             Unlike the first two tools, Tavily retrieves real-time web data instead
#             of generating answers from the LLM.
#         </p>
#     </div>
#
#     <div style="
#         background:white;
#         color:#333;
#         padding:20px;
#         border-radius:15px;
#         margin-top:15px;
#     ">
#         <h2 style="color:#7C3AED;">🚀 Step 3: Execute the Tools</h2>
#
#         <p>
#             Each tool is tested with sample input using:
#         </p>
#
#         <div style="
#             background:#EEF2FF;
#             padding:15px;
#             border-radius:8px;
#             font-family:monospace;
#         ">
#             tool.invoke(...)
#         </div>
#
#         <p>
#             The invoke() method runs the selected tool and returns the result.
#         </p>
#     </div>
#
#     <div style="
#         background:white;
#         color:#333;
#         padding:20px;
#         border-radius:15px;
#         margin-top:15px;
#     ">
#         <h2 style="color:#7C3AED;">📺 Expected Outputs</h2>
#
#         <ul style="line-height:2;">
#             <li>✅ Simple QA Tool returns an answer.</li>
#             <li>✅ Summarizer Tool returns a concise summary.</li>
#             <li>✅ Tavily Search returns current web search results.</li>
#         </ul>
#     </div>
#
#     <div style="
#         margin-top:25px;
#         background:#22C55E;
#         color:white;
#         padding:20px;
#         border-radius:15px;
#         text-align:center;
#         font-size:18px;
#     ">
#         <b>
#         🔄 Overall Workflow
#         <br><br>
#
#         User Input
#         <br>⬇️<br>
#
#         Choose Tool
#         <br>⬇️<br>
#
#         ┌────────────┐
#         <br>
#         │ QA Tool    │
#         <br>
#         │ Summary Tool│
#         <br>
#         │ Search Tool│
#         <br>
#         └────────────┘
#
#         <br>⬇️<br>
#
#         GPT or Tavily Processes Request
#
#         <br>⬇️<br>
#
#         Final Result Displayed
#         </b>
#     </div>
#
#     <div style="
#         margin-top:20px;
#         background:#FEF3C7;
#         color:#92400E;
#         padding:20px;
#         border-radius:15px;
#     ">
#         <b>💡 Layman Explanation</b>
#         <br><br>
#
#         Imagine you have three assistants:
#         <br><br>
#
#         🧠 Assistant 1 answers questions.
#         <br>
#         📝 Assistant 2 creates summaries.
#         <br>
#         🌐 Assistant 3 searches the internet.
#         <br><br>
#
#         All assistants have a specific responsibility and can be used independently.
#         This is exactly how LangChain Tools work.
#     </div>
#
# </div>

# %%
import os
from dotenv import load_dotenv

from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.tools import Tool
from langchain_tavily import TavilySearch

# 🔐 Load API Keys
load_dotenv(dotenv_path=".env")

# 🔸 Initialize LLM
llm = ChatOpenAI(
    model="gpt-4.1-mini",
    temperature=0,
    api_key=os.getenv("OPENAI_API_KEY")
)
# ✅ Tool 1: Simple QA

qa_prompt = ChatPromptTemplate.from_template(
    "Answer clearly: {question}"
)

qa_chain = qa_prompt | llm

qa_tool = Tool(
    name="Simple QA",
    func=lambda question: qa_chain.invoke(
        {"question": question}
    ).content,
    description="Answer factual questions clearly"
)

# ✅ Tool 2: Summarizer

summary_prompt = ChatPromptTemplate.from_template(
    "Summarize the following text:\n\n{text}"
)

summary_chain = summary_prompt | llm

summary_tool = Tool(
    name="Summarizer",
    func=lambda text: summary_chain.invoke(
        {"text": text}
    ).content,
    description="Summarizes input text"
)

# ✅ Tool 3: Web Search (Tavily)

search_tool = TavilySearch(
    max_results=3,
    tavily_api_key=os.getenv("TAVILY_API_KEY")
)

# 🧪 Test Inputs

qa_query = "What is LangGraph in LangChain?"

summary_text = """
LangGraph is a framework for building stateful multi-step agents using LangChain.
It uses graph-based design to model agent workflows and memory.
"""

search_query = "Latest updates on GPT-4o by OpenAI"

# 🚀 Run Tools

print("\n🧠 Simple QA Tool Output:\n")
print(qa_tool.invoke(qa_query))

print("\n📝 Summarizer Tool Output:\n")
print(summary_tool.invoke(summary_text))

print("\n🌐 Web Search Tool Output:\n")
print(search_tool.invoke(search_query))
# Out:
# 🧠 Simple QA Tool Output:
#
# LangGraph in LangChain is a tool or component designed to represent and manage the flow of data and operations within a language model application as a graph structure. It helps visualize and orchestrate how different parts of a language model pipeline—such as prompts, chains, agents, and tools—are connected and interact with each other. This makes it easier to build, debug, and optimize complex workflows involving multiple language model calls and integrations.
#
# 📝 Summarizer Tool Output:
#
# LangGraph is a framework that leverages graph-based design to create stateful, multi-step agents with LangChain, enabling the modeling of agent workflows and memory.
#
# 🌐 Web Search Tool Output:
#
# {'query': 'Latest updates on GPT-4o by OpenAI', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://community.openai.com/t/chatgpt-release-notes-2025-march-27-gpt-4o-a-new-update/1153887', 'title': 'ChatGPT — Release Notes: 2025-March-27 - GPT-4o a new update - Community - OpenAI Developer Community', 'content': '# ChatGPT — Release Notes: 2025-March-27 - GPT-4o a new update\n\nOpenAI just gave GPT-4o a new update. Based on content on OpenAI help page:\n\nThis model is now available in ChatGPT and in the API as the newest snapshot of chatgpt-4o-latest.\n\nWe plan to bring these improvements to a dated model in the API in the coming weeks.\n\nDoes this affect GPT-4o-mini too, or just GPT-4o?\n\nGenerally, I don’t use 4o mini.\n\nBut I just tested, it is same on my end. [...] Thank the gods. The January update was so bad at following instructions, catching and prepresenting nuance, terrible at coding, that I was looking at Gemini, Claude, and DeepSeek as alternatives (turns out they were little better). The subtle, careful, and accurate experience I had come to expect all through 2024 was tossed out the window. My anecdotal experience was that the Jan GPT-4o update was less helpful than the original GPT-3.5 we got in Nov 2022. [...] | 4o model - (ruined after updates)  ChatGPT gpt-4 ,  bug ,  gpt-4o | 4 | 1906 | February 25, 2025 |\n| Gpt 4.5 Expected Release Date?  Community gpt-4 | 10 | 9287 | September 23, 2024 |', 'score': 0.8886914, 'raw_content': None, 'id': '77bfcc-00'}, {'url': 'https://help.openai.com/en/articles/9624314-model-release-notes', 'title': 'Model Release Notes | OpenAI Help Center', 'content': 'We’ve updated GPT-4o for ChatGPT users on all paid tiers. This update to GPT-4o includes improved writing capabilities that are now more natural, audience-aware, and tailored to improve relevance and readability. This model is also better at working with uploaded files, able to provide deeper insights and more thorough responses.\n\n### Update to GPT 4o-mini (November 5, 2024) [...] ## Improvements to GPT-4o (March 27, 2025)\n\nWe’ve made improvements to GPT-4o—it now feels more intuitive, creative, and collaborative, with enhanced instruction-following, smarter coding capabilities, and a clearer communication style.\n\n### Smarter problem-solving in STEM and coding: [...] GPT-4o is now better at understanding and answering questions about visual inputs, with improvements on multimodal benchmarks like MMMU and MathVista. The updated model is more adept at interpreting spatial relationships in image uploads, as well as analyzing complex diagrams, understanding charts and graphs, and connecting visual input with written content. Responses to image uploads will contain richer insights and more accurate guidance in areas like spatial planning and design layouts, as', 'score': 0.87782305, 'raw_content': None, 'id': '6a892a-01'}, {'url': 'https://en.wikipedia.org/wiki/GPT-4o', 'title': 'GPT-4o', 'content': '# GPT-4o\n\n| GPT-4o | |\n --- |\n|  | |\n| Developer | OpenAI |\n| Release | May 13, 2024; 2 years ago (2024-05-13) |\n|  | |\n| Preview release | ChatGPT-4o-latest (March 26, 2025) / March 26, 2025; 17 months ago (2025-03-26) |\n|  | |\n| Predecessor | GPT-4 Turbo |\n| Successor |  OpenAI o1  GPT-4.5  GPT-5 |\n| Type |  Multimodal  Large language model  Generative pre-trained transformer  Foundation model |\n| License | Proprietary |\n| Website | openai.com/index/hello-gpt-4o |\n\n|  | [...] In August 2024, OpenAI introduced a new feature allowing corporate customers to customize GPT-4o using proprietary company data. This customization, known as fine-tuning "Fine-tuning (deep learning)"), enables businesses to adapt GPT-4o to specific tasks or industries, enhancing its utility in areas like customer service and specialized knowledge domains. Previously, fine-tuning was available only on the less powerful model GPT-4o mini. [...] OpenAI retired GPT-4o from ChatGPT on February 13, 202 ...
