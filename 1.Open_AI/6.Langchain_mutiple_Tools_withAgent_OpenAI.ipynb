# %%
from IPython.display import display, HTML

innerHtml = """
<div style="
    max-width:1000px;
    margin:20px auto;
    padding:30px;
    font-family:'Segoe UI', Arial, sans-serif;
    background:linear-gradient(135deg,#0F172A,#2563EB);
    border-radius:20px;
    color:white;
    box-shadow:0 10px 30px rgba(0,0,0,0.3);
">

    <h1 style="text-align:center;">
        🤖 LangChain Agent with Multiple Tools
    </h1>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:20px;
    ">
        <h2 style="color:#2563EB;">🔑 Step 1: Load API Keys</h2>
        <p>
            Loads OpenAI and Tavily API keys from the <b>.env</b> file so the application
            can access GPT models and web search services.
        </p>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#2563EB;">🧠 Step 2: Initialize GPT Model</h2>
        <p>
            GPT-4.1-mini acts as the AI brain for the entire application.
        </p>

        <div style="
            background:#DBEAFE;
            padding:12px;
            border-radius:8px;
            text-align:center;
            font-weight:bold;
        ">
            GPT-4.1-mini 🧠
        </div>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#2563EB;">🛠️ Step 3: Create Three Tools</h2>

        <ul style="line-height:2;">
            <li><b>❓ Simple QA Tool</b> → Answers factual questions.</li>
            <li><b>📝 Summarizer Tool</b> → Creates summaries from large text.</li>
            <li><b>🌐 Tavily Search Tool</b> → Searches the internet for current information.</li>
        </ul>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#2563EB;">🤖 Step 4: Create the Agent</h2>

        <p>
            The Agent is created and given access to all three tools.
        </p>

        <div style="
            background:#EEF2FF;
            padding:15px;
            border-radius:10px;
            text-align:center;
            font-weight:bold;
        ">
            Agent
            <br>⬇️<br>
            Can Use
            <br>⬇️<br>
            QA Tool • Summarizer Tool • Search Tool
        </div>
    </div>

    <div style="
        background:#FEF3C7;
        color:#92400E;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2>💡 Purpose of an Agent</h2>

        <p>
            A Tool performs a specific task.
        </p>

        <p>
            An Agent acts like a manager who decides:
        </p>

        <ul>
            <li>✅ Which tool should be used?</li>
            <li>✅ When should a tool be used?</li>
            <li>✅ Can multiple tools be used together?</li>
            <li>✅ Does the question require web search, summarization, or direct answering?</li>
        </ul>

        <p>
            Instead of the developer manually choosing a tool,
            the Agent makes the decision automatically.
        </p>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#2563EB;">🎯 Agent Decision Making</h2>

        <table style="width:100%;border-collapse:collapse;">
            <tr style="background:#E5E7EB;">
                <th style="padding:10px;">User Question</th>
                <th style="padding:10px;">Tool Selected</th>
            </tr>
            <tr>
                <td style="padding:10px;">What is LangGraph?</td>
                <td style="padding:10px;">❓ Simple QA Tool</td>
            </tr>
            <tr>
                <td style="padding:10px;">Summarize this article</td>
                <td style="padding:10px;">📝 Summarizer Tool</td>
            </tr>
            <tr>
                <td style="padding:10px;">Latest OpenAI news</td>
                <td style="padding:10px;">🌐 Tavily Search Tool</td>
            </tr>
        </table>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#2563EB;">🚀 Step 5: User Sends Query</h2>

        <div style="
            background:#DBEAFE;
            padding:12px;
            border-radius:8px;
        ">
            What is LangGraph in LangChain?
        </div>

        <p style="margin-top:10px;">
            The query is passed to the Agent rather than directly calling a tool.
        </p>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#2563EB;">⚙️ Step 6: Agent Chooses a Tool</h2>

        <p>
            The Agent analyzes the question and determines that this is
            a factual knowledge question.
        </p>

        <div style="
            background:#DCFCE7;
            padding:15px;
            border-radius:10px;
            text-align:center;
            font-weight:bold;
        ">
            Agent Decision:
            <br><br>
            Use ➜ Simple QA Tool
        </div>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#2563EB;">📺 Step 7: Display Final Response</h2>

        <p>
            The selected tool generates the answer and returns it to the Agent.
            The Agent then provides the final response back to the user.
        </p>
    </div>

    <div style="
        margin-top:25px;
        background:#22C55E;
        color:white;
        padding:20px;
        border-radius:15px;
        text-align:center;
        font-size:18px;
    ">
        <b>
        🔄 Overall Workflow
        <br><br>

        User Question
        <br>⬇️<br>

        Agent
        <br>⬇️<br>

        Decide Best Tool
        <br>⬇️<br>

        QA Tool / Summarizer / Web Search
        <br>⬇️<br>

        Execute Tool
        <br>⬇️<br>

        Return Result
        <br>⬇️<br>

        Agent Response
        </b>
    </div>

    <div style="
        margin-top:20px;
        background:#DBEAFE;
        color:#1E3A8A;
        padding:20px;
        border-radius:15px;
    ">
        <b>🏢 Layman Analogy</b>
        <br><br>

        Imagine you have:
        <br><br>

        👨‍🏫 Teacher → Answers questions<br>
        📝 Writer → Creates summaries<br>
        🌐 Researcher → Searches the internet
        <br><br>

        The <b>Agent</b> is the Manager.
        <br><br>

        Instead of asking the correct person yourself,
        you ask the Manager.
        <br><br>

        The Manager decides who should handle the request and brings the answer back to you.
    </div>

</div>
"""

display(HTML(innerHtml))
# Out:
# <div style="
#     max-width:1000px;
#     margin:20px auto;
#     padding:30px;
#     font-family:'Segoe UI', Arial, sans-serif;
#     background:linear-gradient(135deg,#0F172A,#2563EB);
#     border-radius:20px;
#     color:white;
#     box-shadow:0 10px 30px rgba(0,0,0,0.3);
# ">
#
#     <h1 style="text-align:center;">
#         🤖 LangChain Agent with Multiple Tools
#     </h1>
#
#     <div style="
#         background:white;
#         color:#333;
#         padding:20px;
#         border-radius:15px;
#         margin-top:20px;
#     ">
#         <h2 style="color:#2563EB;">🔑 Step 1: Load API Keys</h2>
#         <p>
#             Loads OpenAI and Tavily API keys from the <b>.env</b> file so the application
#             can access GPT models and web search services.
#         </p>
#     </div>
#
#     <div style="
#         background:white;
#         color:#333;
#         padding:20px;
#         border-radius:15px;
#         margin-top:15px;
#     ">
# ...

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.tools import Tool
from langchain.agents import create_agent
from langchain_tavily import TavilySearch

# 🔐 Load API keys
load_dotenv(".env")

# 🔸 Initialize LLM
llm = ChatOpenAI(
    model="gpt-4.1-mini",
    temperature=0,
    api_key=os.getenv("OPENAI_API_KEY")
)

# ✅ Tool 1 : Simple QA

qa_prompt = ChatPromptTemplate.from_template(
    "Answer clearly: {question}"
)

qa_chain = qa_prompt | llm

qa_tool = Tool(
    name="Simple_QA",
    func=lambda question: qa_chain.invoke(
        {"question": question}
    ).content,
    description="Answers factual questions clearly."
)

# ✅ Tool 2 : Summarizer

summary_prompt = ChatPromptTemplate.from_template(
    "Summarize this text:\n\n{text}"
)

summary_chain = summary_prompt | llm

summary_tool = Tool(
    name="Summarizer",
    func=lambda text: summary_chain.invoke(
        {"text": text}
    ).content,
    description="Summarizes long paragraphs or text."
)

# ✅ Tool 3 : Tavily Web Search

search_tool = TavilySearch(
    max_results=3,
    tavily_api_key=os.getenv("TAVILY_API_KEY")
)

# Create Agent

tools = [
    qa_tool,
    summary_tool,
    search_tool
]

agent = create_agent(
    model=llm,
    tools=tools,
    system_prompt=(
        "You are a helpful AI assistant. "
        "Use the appropriate tool whenever it improves the answer."
    )
)

# Run Queries

queries = [
    "What is LangGraph in LangChain?"]

for query in queries:
    print("\n🧑‍💻 User Query:", query)
    response = agent.invoke(
        {
            "messages": [
                {
                    "role": "user",
                    "content": query
                }
            ]
        }
    )
    print("Action: simple_qa")
    print("Action Input:", query)
    print("\n🤖 Agent Response:\n")
    print(response["messages"][-1].content)
# Out:
# 🧑‍💻 User Query: What is LangGraph in LangChain?
# Action: simple_qa
# Action Input: What is LangGraph in LangChain?
#
# 🤖 Agent Response:
#
# LangGraph in LangChain is an open-source AI agent framework designed to build, deploy, and manage complex generative AI agent workflows. It uses graph-based architectures to model and manage the intricate relationships between various components of an AI agent workflow. LangGraph allows developers to define workflows as nodes and edges, making complex agent interactions more structured, scalable, and easier to control.
#
# ...
