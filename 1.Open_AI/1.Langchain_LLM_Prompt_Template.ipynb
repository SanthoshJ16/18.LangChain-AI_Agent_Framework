# %%
from IPython.display import display, HTML

innerHtml = """
<div style="
    max-width:900px;
    margin:20px auto;
    padding:30px;
    font-family:'Segoe UI',Arial,sans-serif;
    background:linear-gradient(135deg,#667eea,#764ba2);
    border-radius:20px;
    color:white;
    box-shadow:0 10px 30px rgba(0,0,0,0.25);
">

    <h1 style="text-align:center;">
        🤖 LangChain + Gemini Workflow
    </h1>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:20px;
    ">
        <h2 style="color:#5B5BD6;">🔑 Step 1: Load API Key</h2>
        <p>
            Reads the Gemini API key from the <b>.env</b> file so the application can securely connect to Gemini.
        </p>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#5B5BD6;">🚀 Step 2: Connect to Gemini</h2>
        <p>
            Initializes the Gemini AI model using the API key and sets the temperature for response generation.
        </p>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#5B5BD6;">📝 Step 3: Create Prompt Template</h2>
        <p>
            Creates a reusable prompt:
        </p>
        <div style="
            background:#f4f4f4;
            padding:10px;
            border-left:5px solid #667eea;
            border-radius:5px;
        ">
            Answer clearly: {question}
        </div>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#5B5BD6;">🔗 Step 4: Create Chain</h2>
        <p>
            Connects the Prompt Template and Gemini model together using LCEL.
        </p>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#5B5BD6;">❓ Step 5: Ask Question</h2>
        <p>
            Sends the user's question:
            <br>
            <b>What is LangGraph in LangChain?</b>
        </p>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#5B5BD6;">💡 Step 6: Generate Response</h2>
        <p>
            Gemini analyzes the question and generates a detailed answer.
        </p>
    </div>

    <div style="
        background:white;
        color:#333;
        padding:20px;
        border-radius:15px;
        margin-top:15px;
    ">
        <h2 style="color:#5B5BD6;">📺 Step 7: Display Result</h2>
        <p>
            The answer is extracted from the response object and displayed to the user.
        </p>
    </div>

    <div style="
        background:#ffffff20;
        margin-top:25px;
        padding:20px;
        border-radius:15px;
        text-align:center;
        font-size:18px;
    ">
        <b>
        🔄 Flow:
        API Key → Gemini → Prompt → Chain → Question → Answer → Display
        </b>
    </div>

</div>
"""

display(HTML(innerHtml))
# Out:
# <div style="
#     max-width:900px;
#     margin:20px auto;
#     padding:30px;
#     font-family:'Segoe UI',Arial,sans-serif;
#     background:linear-gradient(135deg,#667eea,#764ba2);
#     border-radius:20px;
#     color:white;
#     box-shadow:0 10px 30px rgba(0,0,0,0.25);
# ">
#
#     <h1 style="text-align:center;">
#         🤖 LangChain + Gemini Workflow
#     </h1>
#
#     <div style="
#         background:white;
#         color:#333;
#         padding:20px;
#         border-radius:15px;
#         margin-top:20px;
#     ">
#         <h2 style="color:#5B5BD6;">🔑 Step 1: Load API Key</h2>
#         <p>
#             Reads the Gemini API key from the <b>.env</b> file so the application can securely connect to Gemini.
#         </p>
#     </div>
#
#     <div style="
#         background:white;
#         color:#333;
#         padding:20px;
#         border-radius:15px;
#         margin-top:15px;
#     ">
#         <h2 style="color:#5B5BD6;">🚀 Step 2: Connect to Gemini</h2>
# ...

# %%
import os
from dotenv import load_dotenv
#from langchain.chat_models import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI
#from langchain.prompts import PromptTemplate
from langchain_core.prompts import ChatPromptTemplate

# %%
# Load API key
load_dotenv(".env")

# Initialize Gemini LLM
llm = ChatGoogleGenerativeAI(
    model="models/gemini-3.6-flash",   # or gemini-2.5-pro
    google_api_key=os.getenv("GOOGLE_API_KEY"),
    temperature=0
)

# Create Prompt Template
prompt = ChatPromptTemplate.from_template(
    "Answer clearly: {question}"
)

# Create Chain (LCEL)
qa_chain = prompt | llm

# Run a query
query = "What is LanGraph in LangChain?"

response = qa_chain.invoke(
    {"question": query}
)

# Output
print("\nUser Question:", query)
print("\nLLM Answer:", response.content[0]["text"])
# Out:
# C:\Users\xsanthkum\AppData\Local\anaconda3\Lib\site-packages\langchain_google_genai\chat_models.py:3908: UserWarning: Model 'models/gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# User Question: What is LanGraph in LangChain?
#
# LLM Answer: **LangGraph** is a library built by the LangChain team designed to build **complex, stateful, multi-actor AI applications** using a **graph-based structure**.
#
# ...
